1, 7), (8, 1, 8), (8, 1, 9), (8, 3, 2), (8, 3, 6), (8, 3, 7), (8, 3, 8), (8, 4, 2), (8, 4, 6), (8, 4, 7), (8, 4, 8), (8, 5, 2), (8, 5, 6), (8, 5, 7), (8, 5, 8), (8, 5, 9), (8, 6, 4), (8, 6, 9), (8, 7, 1), (8, 7, 2), (8, 7, 6), (8, 7, 7), (8, 7, 9), (8, 8, 1), (8, 8, 2), (8, 8, 6), (8, 8, 7)]
fixed_tuples1 = [(0, 6, 2), (1, 1, 5), (1, 6, 6), (1, 8, 3), (2, 0, 2), (2, 4, 9), (2, 6, 1), (2, 7, 4), (2, 8, 5), (3, 2, 1), (3, 6, 5), (3, 8, 9), (4, 3, 9), (4, 6, 7), (4, 8, 4), (5, 2, 7), (5, 5, 5), (5, 6, 8), (5, 7, 3), (6, 3, 4), (6, 4, 1), (6, 7, 5), (7, 5, 3), (7, 7, 8), (8, 0, 5), (8, 2, 3)]

# %%
from python_package.exact_cover import Exact_cover

# %%
from python_package.sudoku import Sudoku

# %%
# initialize the thesis 4x4 sudoku example as a Sudoku instance
example_sudoku_4x4 = Sudoku("../data/4x4sudoku.csv")

# %%
# Show the sudoku initial state grid
example_sudoku_4x4.plot_grid()

# %%
# Show the initial prefilled cells and the current open tuples
set_tuples = example_sudoku_4x4.set_tuples
example_sudoku_4x4.digit_exclusion()
open_tuples = example_sudoku_4x4.open_tuples
print(f'set_tuples:{set_tuples}')
print(f'open_tuples:{open_tuples}')

#Note, one has to run digit exclusion to get the open tuples
# Out:
# set_tuples:{(0, 0): {1}, (1, 1): {4}, (2, 1): {2}, (3, 0): {3}}
# open_tuples:{(0, 1): {3}, (0, 2): {2, 3, 4}, (0, 3): {2, 3, 4}, (1, 0): {2}, (1, 2): {1, 2, 3}, (1, 3): {1, 2, 3}, (2, 0): {4}, (2, 2): {1, 3, 4}, (2, 3): {1, 3, 4}, (3, 1): {1}, (3, 2): {1, 2, 4}, (3, 3): {1, 2, 4}}

# %%
exact_cover = Exact_cover(open_tuples1, fixed_tuples1, 3)

# %%
exact_cover.generate_dict()
# Out:
# fixed tuples patterns{1: [[None, None, 3, None, 6, None, 2, None, None]], 2: [[2, None, None, None, None, None, 0, None, None]], 3: [[None, None, 8, None, None, 7, None, 5, 1]], 4: [[None, None, None, 6, None, None, None, 2, 4]], 5: [[8, 1, None, None, None, 5, 3, 6, 2]], 6: [[None, None, None, None, None, None, 1, None, None]], 7: [[None, None, 5, None, None, None, 4, None, None]], 8: [[None, None, None, None, None, None, 5, 7, None]], 9: [[None, None, None, 4, 2, None, None, None, 3]]}
# {1: [[0, 0, 3, 0, 6, 0, 2, 4, 5],
#   [0, 0, 3, 0, 6, 0, 2, 4, 7],
#   [0, 0, 3, 0, 6, 0, 2, 4, 8],
#   [0, 0, 3, 0, 6, 0, 2, 8, 5],
#   [0, 0, 3, 0, 6, 0, 2, 8, 7],
#   [0, 0, 3, 0, 6, 0, 2, 8, 8],
#   [0, 0, 3, 0, 6, 1, 2, 4, 5],
#   [0, 0, 3, 0, 6, 1, 2, 4, 7],
#   [0, 0, 3, 0, 6, 1, 2, 4, 8],
#   [0, 0, 3, 0, 6, 1, 2, 8, 5],
#   [0, 0, 3, 0, 6, 1, 2, 8, 7],
#   [0, 0, 3, 0, 6, 1, 2, 8, 8],
#   [0, 0, 3, 0, 6, 4, 2, 4, 5],
#   [0, 0, 3, 0, 6, 4, 2, 4, 7],
#   [0, 0, 3, 0, 6, 4, 2, 4, 8],
# ...
