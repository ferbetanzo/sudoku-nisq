# %%
from python_package.preprocessing import Preprocessing
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from python_package.preprocessing import Preprocessing
#
# ModuleNotFoundError: No module named 'python_package'

# %%
sudoku1 = Preprocessing("../data/easy5.csv")

# %%
sudoku1.plot_sudoku_grid()
sudoku1.general_preprocessing()
