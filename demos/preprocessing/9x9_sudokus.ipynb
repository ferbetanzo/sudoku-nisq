# %% [markdown]
# # **Easy puzzle set**
# ---
# Pre-processing of the set of easy sudokus used in *Encoding Strategies to Solve Sudoku with Quantum Computers*

# %%
from python_package.sudoku import Sudoku

# %%
easy_sudoku_1 = Sudoku("../../data/easy1.csv")
easy_sudoku_1.plot_grid()

# %% [markdown]
# ### First Pre-processing iteration

# %%
easy_sudoku_1.general_preprocessing()
easy_sudoku_1.plot_grid()

# %% [markdown]
# ### Second Pre-processing iteration

# %%
easy_sudoku_1.general_preprocessing()
easy_sudoku_1.plot_grid()

# %% [markdown]
# ### Third Pre-processing iteration

# %%
easy_sudoku_1.general_preprocessing()
easy_sudoku_1.plot_grid()

# %% [markdown]
# ### Fourth Pre-processing iteration

# %%
easy_sudoku_1.general_preprocessing()
easy_sudoku_1.plot_grid()
